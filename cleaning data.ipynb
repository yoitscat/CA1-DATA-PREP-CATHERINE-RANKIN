# %%
# Importing libraries
import pandas as pd
import numpy as np
import seaborn as sns

# Read csv file into a pandas dataframe
df = pd.read_csv("employees.csv")

# %%
df.head()
# Out:
#   First Name  Gender  Salary Bonus % Senior Management             Team
# 0    Douglas    Male   97308   6.945              TRUE        Marketing
# 1     Thomas    Male   61933     NaN              TRUE              NaN
# 2      Maria  Female  130590  11.858             FALSE          Finance
# 3      Jerry    Male     NaN    9.34              TRUE          Finance
# 4      Larry    Male  101004   1.389              TRUE  Client Services

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         931 non-null    object
#  1   Gender             852 non-null    object
#  2   Salary             998 non-null    object
#  3   Bonus %            997 non-null    object
#  4   Senior Management  932 non-null    object
#  5   Team               957 non-null    object
# dtypes: object(6)
# memory usage: 47.0+ KB

# %%
df.isnull().sum()
#null = not a number 
#na = no data, unkown but it is a string and there is still data there
# Out:
# First Name            69
# Gender               148
# Salary                 2
# Bonus %                3
# Senior Management     68
# Team                  43
# dtype: int64

# %%
df.describe()
# Out:
#        First Name  Gender Salary Bonus % Senior Management             Team
# count         931     852    998     997               932              957
# unique        201       3    993     968                 4               13
# top       Marilyn  Female  91462   8.999              TRUE  Client Services
# freq           11     428      2       3               467              105

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female', 'n.a.', nan], dtype=object)

# %%
df['First Name'].unique()
# Out:
# array(['Douglas', 'Thomas', 'Maria', 'Jerry', 'Larry', 'Dennis', 'Ruby',
#        nan, 'Angela', 'Frances', 'Louise', 'Julie', 'Brandon', 'Gary',
#        'Kimberly', 'Lillian', 'Jeremy', 'Shawn', 'Diana', 'Donna', 'Lois',
#        'Matthew', 'Joshua', 'John', 'Craig', 'Scott', 'Terry', 'Benjamin',
#        'Christina', 'Joyce', 'Jean', 'Theresa', 'Rachel', 'Linda',
#        'Stephanie', 'Michael', 'Christine', 'Beverly', 'Marilyn',
#        'Cynthia', 'Roger', 'Bruce', 'Kathy', 'Clarence', 'Chris', 'Nancy',
#        'Todd', 'Alan', 'Sara', 'Karen', 'Carl', '?', 'Irene', 'Paula',
#        'Denise', 'Kathleen', 'Steve', 'Jose', 'Johnny', 'Bobby', 'Bonnie',
#        'Margaret', 'Charles', 'Robin', 'Gerald', 'Christopher', 'Steven',
#        'Doris', 'Annie', 'Janice', 'James', 'Virginia', 'Harry',
#        'Heather', 'Laura', 'Tina', 'Harold', 'Melissa', 'Aaron', 'Jack',
#        'Phyllis', 'Paul', 'Russell', 'Shirley', 'Willie', 'Ashley',
# ...

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female', 'n.a.', nan], dtype=object)

# %%
df['Salary'].unique()
# Out:
# array(['97308', '61933', '130590', nan, '101004', '115163', '65476',
#        '45906', '139852', '63241', '102508', '112807', '109831', '41426',
#        '59414', '90370', '111737', '132940', '81014', '64714', '100612',
#        '90816', '125792', '97950', '37076', '37598', '122367', '124008',
#        '79529', '118780', '88657', '122340', '119082', '95734', '85182',
#        '142032', '57427', '36844', '122173', '99283', '66582', '121918',
#        '73524', '145146', '88010', '114796', '66820', '93581', '113590',
#        '94976', '41126', '49339', '40341', '83677', '102488', '130276',
#        '64715', '72670', '66851', '48866', '106862', '58112', '35203',
#        '77834', '61310', '125250', '51178', '84834', '100863', '84692',
#        '118172', '54043', '90582', '62096', '104897', '131604', '107391',
#        '114797', '115814', '137126', '47369', '35095', '148115', '83072',
#        '100238', '103495', '144887', '64088', '51082', '91719', '128771',
# ...

# %%
df['Bonus %'].unique()
# Out:
# array(['6.945', nan, '11.858', '9.34', '1.389', '10.125', '10.012',
#        '11.598', '18.523', '7.524', '15.132', '12.637', '17.492', '5.831',
#        '1.256', '7.369', '6.414', '19.082', '1.894', '4.934', '13.645',
#        '18.816', '5.042', '13.873', '18.576', '7.757', '5.218', '13.464',
#        '7.008', '9.096', '12.752', '6.417', '16.18', '19.096', '16.675',
#        '12.599', '9.557', '5.574', '7.797', '2.665', '11.308', '15.835',
#        '5.207', '7.482', '13.886', '6.796', '6.083', '3.055', '13.83',
#        '14.009', '1.695', '17.578', '8.999', '17.653', '16.084', '15.107',
#        '1.481', '11.279', '4.271', '3.699', '19.414', '18.04', '18.771',
#        '12.428', '2.672', '9.735', '14.33', '4.382', '6.617', '16.194',
#        '3.833', '4.709', '17.029', '?', '7.353', '1.26', '5.965', '4.99',
#        '15.602', '14.822', '8.379', '6.539', '7.511', '3.887', '17.29',
#        '8.276', '6.155', '11.955', '11.583', '8.309', '12.506', '1.601',
# ...

# %%
df['Senior Management'].unique()
# Out:
# array(['TRUE', 'FALSE', nan, 'n.a.', '?'], dtype=object)

# %%
df['Team'].unique()
# Out:
# array(['Marketing', nan, 'Finance', 'Client Services', 'Legal', 'Product',
#        'Engineering', 'Business Development', 'Human Resources', 'Sales',
#        'na', 'Distribution', 'n.a.', '?'], dtype=object)

# %%
missing_value=['n.a.','?','NA','n/a','na','--']

# %%
df=pd.read_csv('employees.csv', na_values=missing_value)

# %%
df.isnull().sum()
# Out:
# First Name            70
# Gender               149
# Salary                 5
# Bonus %                4
# Senior Management     71
# Team                  48
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         930 non-null    object
#  1   Gender             851 non-null    object
#  2   Salary             995 non-null    float64
#  3   Bonus %            996 non-null    float64
#  4   Senior Management  929 non-null    object
#  5   Team               952 non-null    object
# dtypes: float64(2), object(4)
# memory usage: 47.0+ KB

# %%
df.describe()#mdeian and mean similar = not skewed distribution
# Out:
#               Salary     Bonus %
# count     995.000000  996.000000
# mean    90522.329648   10.215586
# std     32880.654889    5.532077
# min     35013.000000    1.015000
# 25%     62412.500000    5.429500
# 50%     90370.000000    9.850000
# 75%    118582.000000   14.841250
# max    149908.000000   19.944000

# %%
new_df['Salary'].fillna(-999)
# Out:
# 0       97308.0
# 2      130590.0
# 4      101004.0
# 6       65476.0
# 9      139852.0
#          ...
# 994     98874.0
# 996     42392.0
# 997     96914.0
# 998     60500.0
# 999    129949.0
# Name: Salary, Length: 742, dtype: float64

# %%
#1 ignore data - drop observations/columns(features)

# %%
new_df=df.dropna(axis=0)#row/observation

# %%
new_df.isnull().values.any()
# Out:
# False

# %%
new_df.shape
# Out:
# (742, 6)

# %%
new_df=df.dropna(axis=0)

# %%
new_df.isnull().values.any()
# Out:
# False

# %%
new_df.shape
# Out:
# (742, 6)

# %%
new_df=df

# %%
new_df['Salary']=new_df['Salary'].fillna(-999)

# %%
new_df['Salary'].head()
# Out:
# 0     97308.0
# 1     61933.0
# 2    130590.0
# 3      -999.0
# 4    101004.0
# Name: Salary, dtype: float64
